# %%
import sys
sys.path.append('./')  # Añadir la carpeta actual (src) al path

from extraction import ejecutar_proceso_extraccion  # Importar la función desde extraction.py

# Ejecutar la función
ejecutar_proceso_extraccion()  # Llamamos a la función
# Out:
# Tablas en la base de datos: ['2019-Dec', '2019-Nov', '2019-Oct', '2020-Feb', '2020-Jan']
# Octubre: 407925 filas, 10 columnas
# Noviembre: 462833 filas, 10 columnas
# Diciembre: 351304 filas, 10 columnas
# Enero: 443224 filas, 10 columnas
# Febrero: 429790 filas, 10 columnas
#
# Total registros: 2095076 filas
# Tablas guardadas como CSV en '../data/originals/'
# Tablas unidas mediante apilación vertical
# Copia del DataFrame creada para trabajar
# DataFrame combinado guardado como 'datos_integrados.csv'
# DataFrame de trabajo guardado como 'ecommerce.csv'
#
# Registros totales tras integración: 2095076 filas y 10 columnas
#
# --- Primeros registros del DataFrame original (data) ---
#    index               event_time event_type  product_id          category_id  \
# 0     68  2019-10-01 00:01:46 UTC       view     5843665  1487580005092295511
# 1     72  2019-10-01 00:01:55 UTC       cart     5868461  1487580013069861041
# ...

# %%
# 📦 ecommerce
# │── main.py                      
# │── notebook.ipynb                 
# │
# │── 📁 data/                        
# │   ├── 📁 raw/                     
#          ├── 📁 ecommerce.db/                       
# │   ├── 📁 processed/               
# │   ├── 📁 originals/               
# │   ├── 📁 validation/           
# │
# │── 📁 notebooks/                   
# │   ├── 00_project.ipynb           
# │   ├── 01_extraction.ipynb         
# │   ├── 02_cleaning.ipynb          
# │   ├── 03_transformation.ipynb     
# │   ├── 04_analysis.ipynb          
# │
# │── 📁 src/                        
# │   ├── __init__.py                
# │   ├── extraction.py            
# │   ├── cleaning.py              
# │   ├── transformation.py        
# │   ├── analysis.py             
# │   ├── 📁 utils/
